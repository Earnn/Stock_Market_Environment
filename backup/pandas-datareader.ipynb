# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.style.use("ggplot")
import pandas_datareader.data as web
import datetime

# %%
sym="PTT.BK"
start = datetime.datetime(1970, 9, 16)
end = datetime.datetime(2017, 9, 15)
df = web.DataReader(sym, 'yahoo', start, end)
#df.tail()
df.plot(y=["Adj Close"],title=sym,figsize=(12,4))

# %%
sym="AOT.BK"
start = datetime.datetime(2016, 9, 16)
end = datetime.datetime(2017, 9, 15)
df = web.DataReader(sym, 'yahoo-actions', start, end)

# %%
df.head()
# Out:
#             value    action
# Date
# 2017-02-09   0.00     SPLIT
# 2016-12-08   6.83  DIVIDEND

# %%
q
