# %%
import json
import requests

rsp = requests.get('https://finance.google.com/finance?q=BKK:SIRI&output=json')
if rsp.status_code in (200,):

    # This magic here is to cut out various leading characters from the JSON 
    # response, as well as trailing stuff (a terminating ']\n' sequence), and then
    # we decode the escape sequences in the response
    # This then allows you to load the resulting string
    # with the JSON module.
    fin_data = json.loads(rsp.content[6:-2].decode('unicode_escape'))

    # print out some quote data
    print('Opening Price: {}'.format(fin_data['op']))
    print('Price/Earnings Ratio: {}'.format(fin_data['pe']))
    print('52-week high: {}'.format(fin_data['hi52']))
    print('52-week low: {}'.format(fin_data['lo52']))
# Out:
# Opening Price: 2.26
# Price/Earnings Ratio: 9.26
# 52-week high: 2.38
# 52-week low: 1.50

# %%
fin_data
# Out:
# {u'avvo': u'95.03M',
#  u'beta': u'',
#  u'c': u'+0.02',
#  u'ccol': u'chg',
#  u'cp': u'0.88',
#  u'dy': u'5.70',
#  u'e': u'BKK',
#  u'eo': u'',
#  u'eps': u'0.25',
#  u'events': [{u'date': u'Aug 21, 2017',
#    u'desc': u'Sansiri PCL at Macquarie ASEAN Conference',
#    u'future': 0,
#    u'time': u''}],
#  u'exchange': u'BKK',
#  u'f_annual_date': u'',
#  u'f_recent_quarter_date': u'',
#  u'f_reuters_url': u'http://stocks.us.reuters.com/stocks/ratios.asp?rpc=66&symbol=SIRI.BK',
#  u'f_ttm_date': u'',
#  u'financials': [{u'f_figures': [],
#    u'f_type': u'Income&nbsp;Statement',
#    u'url': u'http://www.google.com/finance?fstype=ii&q=BKK:SIRI'},
#   {u'f_figures': [],
#    u'f_type': u'Balance&nbsp;Sheet',
#    u'url': u'http://www.google.com/finance?fstype=bi&q=BKK:SIRI'},
#   {u'f_figures': [],
#    u'f_type': u'Cash&nbsp;Flow',
#    u'url': u'http://www.google.com/finance?fstype=ci&q=BKK:SIRI'}],
#  u'fwpe': u'',
#  u'hi': u'2.28',
#  u'hi52': u'2.38',
#  u'id': u'322220347923811',
#  u'instown': u'',
#  u'keyratios': [{u'annual': u'9.96%',
#    u'recent_quarter': u'9.42%',
#    u'title': u'Net profit margin',
#    u'ttm': u'10.41%'},
#   {u'annual': u'14.43%',
#    u'recent_quarter': u'15.35%',
#    u'title': u'Operating margin',
#    u'ttm': u'15.36%'},
#   {u'annual': u'15.23%',
#    u'recent_quarter': u'',
#    u'title': u'EBITD margin',
#    u'ttm': u'16.48%'},
#   {u'annual': u'4.75%',
#    u'recent_quarter': u'4.27%',
#    u'title': u'Return on average assets',
#    u'ttm': u'4.87%'},
#   {u'annual': u'12.23%',
#    u'recent_quarter': u'11.36%',
#    u'title': u'Return on average equity',
#    u'ttm': u'12.84%'},
#   {u'annual': u'-',
#    u'recent_quarter': u'1,357',
#    u'title': u'Employees',
#    u'ttm': u'-'}],
#  u'kr_annual_date': u'2016',
#  u'kr_recent_quarter_date': u"Q2 (Jun '17)",
#  u'kr_ttm_date': u'TTM',
#  u'l': u'2.28',
#  u'ldiv': u'0.05',
#  u'lo': u'2.22',
#  u'lo52': u'1.50',
#  u'management': [{u'age': u'80',
#    u'name': u'Kowit Posayanon',
#    u'title': u'Chairman of the Board, Independent Director'},
#   {u'age': u'54',
#    u'name': u'Aphichart Chutrakun',
#    u'title': u'Vice Chairman of the Board, President'},
#   {u'age': u'49',
#    u'name': u'Wanchak Buranasiri',
#    u'title': u'Chief Operating Officer, Director'},
#   {u'age': u'54',
#    u'name': u'Somchai Charnthanawet',
#    u'title': u'Vice President of Finance, Executive Director, Director'},
#   {u'age': u'43',
#    u'name': u'Wilasinee Det-amornthan',
#    u'title': u'Senior Managing Director of Project Management and Marketing 2, Executive Director'},
#   {u'age': u'55',
#    u'name': u'Natthalak Sakunpunyaphorn',
#    u'title': u'Executive Director, Senior Managing Director of Investor Relations and Human Resources'},
#   {u'age': u'48',
#    u'name': u'Phornchai Chaimongkhonsap',
#    u'title': u'Senior Managing Director of Project Management and Marketing'},
#   {u'age': u'47',
#    u'name': u'Chukiat Chumthong',
#    u'title': u'Senior Managing Director of Government Affairs'},
#   {u'age': u'51',
#    u'name': u'Thasanin Maha-ammatayathibodi',
#    u'title': u'Senior Managing Director of Home Care'},
#   {u'age': u'42',
#    u'name': u'Sirinthra Mongkhonnawin',
#    u'title': u'Senior Managing Director of Investor Relations and Organizational Development'}],
#  u'mc': u'32.57B',
#  u'moreresources': [],
#  u'name': u'Sansiri Public Company Limited',
#  u'op': u'2.26',
#  u'pe': u'9.26',
#  u'related': [{u'c': u'+0.02',
#    u'ccol': u'chg',
#    u'cp': u'0.88',
#    u'e': u'BKK',
#    u'id': u'322220347923811',
#    u'l': u'2.28',
#    u'mc': u'32.57B',
#    u'name': u'Sansiri Public Company Limited',
#    u't': u'SIRI'},
#   {u'c': u'0.000',
#    u'ccol': u'chb',
#    u'cp': u'0.00',
#    u'e': u'BKK',
#    u'id': u'220209447601240',
#    u'l': u'0.300',
#    u'mc': u'2.41B',
#    u'name': u'Triton Holding PCL',
#    u't': u'TRITN-F'},
#   {u'c': u'-0.01',
#    u'ccol': u'chr',
#    u'cp': u'-0.65',
#    u'e': u'BKK',
#    u'id': u'842447575925351',
#    u'l': u'1.53',
#    u'mc': u'1.22B',
#    u'name': u'TV Thunder PCL',
#    u't': u'TVT'},
#   {u'c': u'0.000',
#    u'ccol': u'chb',
#    u'cp': u'0.00',
#    u'e': u'BKK',
#    u'id': u'208877661256305',
#    u'l': u'0.630',
#    u'mc': u'2.56B',
#    u'name': u'Nation Multimedia Group Public Co. Ltd.',
#    u't': u'NMG'},
#   {u'c': u'-0.30',
#    u'ccol': u'chr',
#    u'cp': u'-1.73',
#    u'e': u'BKK',
#    u'id': u'1049515520324905',
#    u'l': u'17.00',
#    u'mc': u'34.00B',
#    u'name': u'BEC World Public Company Limited',
#    u't': u'BEC'},
#   {u'c': u'0.00',
#    u'ccol': u'chb',
#    u'cp': u'0.00',
#    u'e': u'BKK',
#    u'id': u'298490717743848',
#    u'l': u'6.65',
#    u'mc': u'1.43B',
#    u'name': u'Pico (Thailand) PCL',
#    u't': u'PICO'},
#   {u'c': u'0.00',
#    u'ccol': u'chb',
#    u'cp': u'0.00',
#    u'e': u'BKK',
#    u'id': u'207612638493148',
#    u'l': u'11.40',
#    u'mc': u'9.35B',
#    u'name': u'GMM Grammy Public Company Limited',
#    u't': u'GRAMMY'},
#   {u'c': u'+0.15',
#    u'ccol': u'chg',
#    u'cp': u'1.86',
#    u'e': u'BKK',
#    u'id': u'620352721813288',
#    u'l': u'8.20',
#    u'mc': u'19.05B',
#    u'name': u'Golden Land Property Development PCL',
#    u't': u'GOLD'},
#   {u'c': u'+0.03',
#    u'ccol': u'chg',
#    u'cp': u'1.57',
#    u'e': u'BKK',
#    u'id': u'772564450498784',
#    u'l': u'1.94',
#    u'mc': u'7.29B',
#    u'name': u'Pace Development Corp PCL',
#    u't': u'PACE'},
#   {u'c': u'0.00',
#    u'ccol': u'chb',
#    u'cp': u'0.00',
#    u'e': u'BKK',
#    u'id': u'310526263529721',
#    u'l': u'3.06',
#    u'mc': u'2.63B',
#    u'name': u'Major Development PCL',
#    u't': u'MJD'},
#   {u'c': u'0.00',
#    u'ccol': u'chb',
#    u'cp': u'0.00',
#    u'e': u'BKK',
#    u'id': u'397939965550269',
#    u'l': u'11.40',
#    u'mc': u'16.82B',
#    u'name': u'L.P.N. Development PCL',
#    u't': u'LPN'}],
#  u'shares': u'14.29B',
#  u'summary': [{u'address': u', Thanonphayathai, Rajthevi, BANGKOK, 10400, Thailand',
#    u'fax': u'+66-22-013905',
#    u'overview': u"Sansiri Public Company Limited is a Thailand-based real estate developer. The Company and its subsidiaries operate three principal business segments based on its products and services, which are property development business segment, building management and real estate brokerage business segment, as well as other business segment. The property development segment involves the development of land and housing projects, residential condominium projects, serviced apartments for rent, and office buildings for rent. The building management and real estate brokerage segment provides services of building management and real estate brokerage mainly to the Company\xe2\x80\x99s projects. Its other business segment involves hotel, medical spa and education business. The Company's subsidiaries include Chanachai Limited, Plus Property Company Limited and Sansiri Venture Company Limited.",
#    u'phone': u'+66-22-013905',
#    u'url': u'http://www.sansiri.com'}],
#  u'symbol': u'SIRI',
#  u't': u'SIRI',
#  u'vo': u'88.79M'}
