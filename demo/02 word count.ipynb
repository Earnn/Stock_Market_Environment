# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is A8BF-C894
#
#  Directory of C:\Users\Wasit\Documents\GitHub\data_analytics\demo
#
# 18/09/2017  01:02    <DIR>          .
# 18/09/2017  01:02    <DIR>          ..
# 18/09/2017  01:02    <DIR>          .ipynb_checkpoints
# 18/09/2017  01:02            22,644 01 Variable.ipynb
# 17/09/2017  22:42            16,065 02 word count.ipynb
# 17/09/2017  22:36             5,902 03 Python Class.ipynb
# 17/09/2017  22:42             1,191 04 module myrect.ipynb
# 03/03/2017  16:36            96,644 05 Titanic Survival Prediction .ipynb
# 10/03/2017  14:02           130,321 06 Titanic Clustering.ipynb
# 18/09/2017  00:58           844,805 10 Trading.ipynb
# 18/09/2017  00:58    <DIR>          data_set
# 13/07/2017  12:07             4,084 Little Red Riding Hood.txt
# 18/09/2017  00:59    <DIR>          myrect
# 02/03/2017  16:18            61,194 train.csv
#                9 File(s)      1,182,850 bytes
# ...

# %%
with open("Little Red Riding Hood.txt", "r") as f:
    data=f.read()

# %%
print(data)
# Out:
# Once upon a time there lived in a certain village a little country girl, the prettiest creature who was ever seen. Her mother was excessively fond of her; and her grandmother doted on her still more. This good woman had a little red riding hood made for her. It suited the girl so extremely well that everybody called her Little Red Riding Hood.
# One day her mother, having made some cakes, said to her, "Go, my dear, and see how your grandmother is doing, for I hear she has been very ill. Take her a cake, and this little pot of butter."
#
# Little Red Riding Hood set out immediately to go to her grandmother, who lived in another village.
#
# ...

# %%
hist={}
for word in data.split():
    hist[word]=hist.get(word,0)+1

# %%
hist
# Out:
# {'"All': 5,
#  '"Does': 1,
#  '"Go,': 1,
#  '"Grandmother,': 5,
#  '"I': 1,
#  '"It': 1,
#  '"Oh': 1,
#  '"Pull': 2,
#  '"Put': 1,
#  '"Well,"': 1,
#  '"Who\'s': 2,
#  '"Your': 1,
#  '"and': 1,
#  '"it': 1,
#  '"who': 1,
#  '"wolf,"': 1,
#  'And': 1,
#  'And,': 1,
#  'As': 1,
#  'Children,': 1,
#  'He': 3,
#  'Her': 1,
#  'Hood': 3,
#  'Hood,': 4,
#  'Hood,"': 1,
#  'Hood.': 1,
#  'Hood;': 1,
#  'I': 3,
#  "I'll": 2,
#  'It': 2,
#  'Little': 10,
#  'Moral:': 1,
#  'Once': 1,
#  'One': 1,
#  'Red': 10,
#  'Riding': 10,
#  'She': 1,
#  'Take': 1,
#  'The': 6,
#  'There': 1,
#  'This': 1,
#  'a': 18,
#  'afraid;': 1,
#  'after': 1,
#  'afterwards': 1,
#  'all': 1,
#  'all.': 1,
#  'also': 1,
#  'am': 1,
#  'amazed': 1,
#  'and': 29,
#  'another': 1,
#  'answered': 1,
#  'answered,': 1,
#  'are': 4,
#  'arms': 1,
#  'arrived': 1,
#  'as': 4,
#  'asked': 1,
#  'at': 6,
#  'ate': 2,
#  'attractive,': 1,
#  'be': 1,
#  'because': 2,
#  'bed': 1,
#  'bed,': 2,
#  'bed.': 1,
# ...
